# %% [markdown]
# ## Imports

# %%
# %matplotlib inline

from osgeo import osr, gdal

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import re
import math

from PIL import Image, ImageDraw
import fiona

from copy import deepcopy

sns.set(color_codes=True)

# %% [markdown]
# ## Read location of Roads

# %%
datafile = '../data/roads/kolovai-tonga_planet_osm_line_lines.shp'

possible_tags = set()

coll_list = []

with fiona.drivers():
    with fiona.open(datafile) as source:
        for coll in source:
            print(coll)
            coll_list.append(coll)

possible_tags
# Out:
# {'type': 'Feature', 'id': '0', 'geometry': {'type': 'LineString', 'coordinates': [(-175.33982444635888, -21.10495236721501), (-175.3398235, -21.1049178), (-175.3398188, -21.1048445), (-175.3398053, -21.1046368), (-175.3397978, -21.1045646), (-175.339776, -21.1043561), (-175.339768, -21.104306), (-175.3397564, -21.1042342), (-175.3397214, -21.103941), (-175.3397154, -21.1038961), (-175.3396651, -21.1035112), (-175.3396577, -21.1034614), (-175.3396442, -21.1033853), (-175.3396268, -21.103287), (-175.3395877, -21.1030623), (-175.3395592, -21.102898), (-175.3395548, -21.1028728), (-175.3395306, -21.1027333), (-175.3394113, -21.1021326), (-175.3393717, -21.1018988), (-175.339338, -21.1016779), (-175.3393221, -21.1015735), (-175.3392926, -21.1012682), (-175.3393043, -21.1010574), (-175.3393126, -21.1009074), (-175.3393205, -21.1006938), (-175.3393387, -21.1004127), (-175.3393556, -21.1001522), (-175.3393576, -21.10004), (-175.3393578, -21.1000243), (-175.3393612, -21.0998348), (-175.3393664, -21.0995429), (-175.3393891, -21.0989285), (-175.3393915, -21.0988756), (-175.3394186, -21.0982729), (-175.33942, -21.0981403), (-175.3394441, -21.0975097), (-175.3394599, -21.0972328), (-175.3394627, -21.097183), (-175.3394781, -21.0969118), (-175.3394817, -21.0968734), (-175.3395436, -21.0962809), (-175.3395503, -21.0962196), (-175.3396259, -21.0956034), (-175.3396399, -21.0954852), (-175.3397068, -21.0950205), (-175.3397955, -21.0944041)]}, 'properties': OrderedDict([('osm_id', '41980161'), ('bridge', None), ('highway', 'tertiary'), ('layer', None), ('name', 'Hala Hihifo'), ('oneway', None), ('smoothness', None), ('surface', None), ('tunnel', None), ('width', None), ('z_index', '4')])}
# {'type': 'Feature', 'id': '1', 'geometry': {'type': 'LineString', 'coordinates': [(-175.3396577, -21.1034614), (-175.3395358, -21.1034839), (-175.3391762, -21.103579), (-175.3390168, -21.1036365), (-175.3387452, -21.1037128), (-175.3386352, -21.1037429), (-175.3385134, -21.1037656), (-175.3375761, -21.104035), (-175.3375048, -21.1040555), (-175.3373815, -21.1040909)]}, 'properties': OrderedDict([('osm_id', '168984864'), ('bridge', None), ('highway', 'residential'), ('layer', None), ('name', None), ('oneway', None), ('smoothness', None), ('surface', None), ('tunnel', None), ('width', None), ('z_index', '3')])}
# {'type': 'Feature', 'id': '2', 'geometry': {'type': 'LineString', 'coordinates': [(-175.3385134, -21.1037656), (-175.3382634, -21.1026527), (-175.3382529, -21.1026056), (-175.3381486, -21.102084), (-175.3380421, -21.1015395), (-175.3380193, -21.1014227), (-175.3379783, -21.1012132), (-175.3378991, -21.1008341), (-175.3377247, -21.1000064), (-175.3377101, -21.099937), (-175.3376537, -21.0996192), (-175.337637, -21.0993458), (-175.3376871, -21.0985463), (-175.3377025, -21.0985142), (-175.337729, -21.0984965), (-175.3377669, -21.0984742), (-175.3378087, -21.0984624), (-175.33942, -21.0981403)]}, 'properties': OrderedDict([('osm_id', '168984865'), ('bridge', None), ('highway', 'residential'), ('layer', None), ('name', None), ('oneway', None), ('smoothness', None), ('surface', None), ('tunnel', None), ('width', None), ('z_index', '3')])}
# {'type': 'Feature', 'id':
), ('layer', None), ('name', None), ('oneway', None), ('smoothness', None), ('surface', None), ('tunnel', None), ('width', None), ('z_index', '3')])}
# {'type': 'Feature', 'id': '238', 'geometry': {'type': 'LineString', 'coordinates': [(-175.3461677, -21.0959547), (-175.3461327, -21.0959711), (-175.3460891, -21.0959917), (-175.3460502, -21.0960105), (-175.3460059, -21.0960255), (-175.3459758, -21.0960337), (-175.345953, -21.0960456), (-175.3459302, -21.0960599), (-175.3459, -21.096075), (-175.3458651, -21.0960762), (-175.3458316, -21.0960756), (-175.3458088, -21.0960762), (-175.3457796, -21.0960768), (-175.3457277, -21.0960603), (-175.3456831, -21.0960562), (-175.3456586, -21.0960527), (-175.3456267, -21.0960556), (-175.3455831, -21.0960518)]}, 'properties': OrderedDict([('osm_id', '550412674'), ('bridge', None), ('highway', 'path'), ('layer', None), ('name', None), ('oneway', None), ('smoothness', None), ('surface', 'grass'), ('tunnel', None), ('width', None), ('z_index', '3')])}
# set()

# %% [markdown]
# ## Reading Image

# %%
datafile = gdal.Open("../data/aerial_image/kolovai.tif")
bnd1 = datafile.GetRasterBand(1).ReadAsArray()
bnd2 = datafile.GetRasterBand(2).ReadAsArray()
bnd3 = datafile.GetRasterBand(3).ReadAsArray()
nx = datafile.RasterXSize # Raster xsize
ny = datafile.RasterYSize # Raster ysize

img = np.dstack((bnd1, bnd2, bnd3))

# %%
img = Image.fromarray(img)

print(img.size)
# Out:
# (17761, 25006)

# %% [markdown]
# ### Retrieve Latitude and Longitude of Image

# %%
old_cs= osr.SpatialReference()
old_cs.ImportFromWkt(datafile.GetProjectionRef())

# create the new coordinate system
wgs84_wkt = """
GEOGCS["WGS 84",
    DATUM["WGS_1984",
        SPHEROID["WGS 84",6378137,298.257223563,
            AUTHORITY["EPSG","7030"]],
        AUTHORITY["EPSG","6326"]],
    PRIMEM["Greenwich",0,
        AUTHORITY["EPSG","8901"]],
    UNIT["degree",0.01745329251994328,
        AUTHORITY["EPSG","9122"]],
    AUTHORITY["EPSG","4326"]]"""
new_cs = osr.SpatialReference()
new_cs.ImportFromWkt(wgs84_wkt)

# create a transform object to convert between coordinate systems
transform = osr.CoordinateTransformation(old_cs, new_cs) 

#get the point to transform, pixel (0,0) in this case
W = datafile.RasterXSize
H = datafile.RasterYSize
gt = datafile.GetGeoTransform()
minx = gt[0]
miny = gt[3] + W*gt[4] + H*gt[5] 
maxx = gt[0] + W*gt[1] + H*gt[2]
maxy = gt[3]

#get the coordinates in lat long
xgeo0, ygeo0, _ = transform.TransformPoint(minx, miny)
xgeoN, ygeoN, _ = transform.TransformPoint(maxx, maxy)

# %%
print(xgeo0, ygeo0)
print(xgeoN, ygeoN)
# Out:
# -175.34907207131698 -21.104930856349313
# -175.33536665317192 -21.08692801644621

# %% [markdown]
# ## Process and Chunk

# %% [markdown]
# ### Coordinate Converter

# %%
class Converter:
    def __init__(self, geo0, geoN, img_shape):
        self.xgeo0, self.ygeo0 = geo0
        self.xgeoN, self.ygeoN = geoN
        self.W, self.H = img_shape
        print(img_shape)
    
    def geo_2_pixel(self, x, y):
        x_pix = ((x - self.xgeo0)/abs(self.xgeoN - self.xgeo0)) * self.W
        y_pix = ((y - self.ygeo0)/abs(self.ygeoN - self.ygeo0)) * self.H
        
        return int(round(x_pix)), int(round(y_pix))

def world2Pixel(geoMatrix, x, y):
    """
    Uses a gdal geomatrix (gdal.GetGeoTransform()) to calculate
    the pixel location of a geospatial coordinate 
    """
    ulX = geoMatrix[0]
    ulY = geoMatrix[3]
    xDist = geoMatrix[1]
    yDist = geoMatrix[5]
    rtnX = geoMatrix[2]
    rtnY = geoMatrix[4]
    pixel = int((x - ulX) / xDist)
    line = int((ulY - y) / yDist)
    
    return (pixel, line)

transform2 = osr.CoordinateTransformation(new_cs, old_cs)

# %% [markdown]
# ### Mark roads on copy of original image

# %%
loc_converter = Converter((xgeo0, ygeo0), (xgeoN, ygeoN), img.size)

marked_img = deepcopy(img)

draw_zone = ImageDraw.Draw(marked_img)
# Out:
# (17761, 25006)

# %%
road = []
y_max = 0
x_max = 0
x_min, y_min = marked_img.size
for loc in coll_list[0]['geometry']['coordinates']:
#     x, y = loc_converter.geo_2_pixel(loc[0], loc[1])
    x_i, y_i, _ = transform.TransformPoint(loc[0], loc[1])
    x, y = world2Pixel(gt, x_i, y_i)
    if x < 0 or y < 0:
        continue
    road.append((x, y))
    y_max = max(y_max, y)
    x_max = max(x_max, x)
    x_min = min(x_min, x)
    y_min = min(y_min, y)
    
print(x_min, y_min)
print(x_max, y_max)

Image.MAX_IMAGE_PIXELS = None
    
draw_zone.polygon(road, outline=(255, 0, 0, 255), fill=(255, 0, 0, 255))
marked_img.crop((x_min, y_min, x_max, y_max)).show()
# Out:
# 17761 25006
# 227236764 27965432
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-29-218be4288931> in <module>()
#      21
#      22 draw_zone.polygon(road, outline=(255, 0, 0, 255), fill=(255, 0, 0, 255))
# ---> 23 marked_img.crop((x_min, y_min, x_max, y_max)).show()
#
# ~/anaconda3/lib/python3.6/site-packages/PIL/Image.py in crop(self, box)
#    1074
#    1075         self.load()
# -> 1076         return self._new(self._crop(self.im, box))
#    1077
#    1078     def _crop(self, im, box):
#
# ~/anaconda3/lib/python3.6/site-packages/PIL/Image.py in _crop(self, im, box)
#    1097         _decompression_bomb_check((x1, y1))
#    1098
# -> 1099         return im.crop((x0, y0, x1, y1))
#    1100
#    1101     def draft(self, mode, size):
#
# MemoryError:

# %% [markdown]
# ### Slice marked image

# %%
img_w, img_h = marked_img.size

slice_x = 1000
slice_y = 1000

Image.MAX_IMAGE_PIXELS = None

max_y = int(math.ceil(img_h/slice_y))
max_x = int(math.ceil(img_w/slice_x))


for y_start in range(0, max_y):
    for x_start in range(0, max_x):
        left = slice_x * x_start
        upper = slice_y * y_start
        bbox = (left, upper, left+slice_x, upper+slice_y)
        working_slice = marked_img.crop(bbox)
        
        working_slice.save("../data/aerial_image/slices/marked__x_"+str(left)+"-"+str(left+slice_x)+"__y_"+ \
                           str(upper)+"-"+str(upper+slice_y)+".png")
